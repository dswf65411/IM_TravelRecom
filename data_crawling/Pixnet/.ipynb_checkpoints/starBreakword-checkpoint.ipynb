# %%
from pymongo import MongoClient
from pprint import pprint

# %%
def replace_dot(strin):
    '''
        input  :str
        output :str with "," "，" "、" "。" "！" "!" "？" "?"... replece by " ", and 全形字 replaced by 半形字
    '''
    replaceDot = set([",","，","、","。","！","!","？","?",":","：",";","；","「","」","【","】","（","）","『","』","．",
                     "「","」","【","】","『","』",'‘', '’', '“', '”', '〝', '〞', '‵', '′', '〃','^','~','.', 
                      '～', '＄', '％', '＠', '＆', '＃', '＊', '‧', '；', '︰','…', '‥', '﹐', '﹒', '˙', '· ﹔',
                      '﹕', '‘', '’', '“', '”', '〝', '〞', '‵', '′', '〃', '_','=','＝','+','-','(',')',' ']
                    )
#   replaceDot = set(["「","」","【","】","『","』",'‘', '’', '“', '”', '〝', '〞', '‵', '′', '〃'])
    replaceDot2 = set(['，', '、', '。', '．', '？', '！', '～', '＄', '％', '＠', '＆', '＃', '＊', '‧', '；', '︰','…', '‥', '﹐', '﹒', '˙', '· ﹔', '﹕', '‘', '’', '“', '”', '〝', '〞', '‵', '′', '〃'])
    replaceBig = "ＡＢＣＤＥＦＧＨＩＪＫＬＭＮＯＰＱＲＳＴＵＶＷＸＹＺａｂｃｄｅｆｇｈｉｊｋｌｍｎｏｐｑｒｓｔｕｖｗｘｙｚ１２３４５６７８９０"
    replaceSmall="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz1234567890"
    for dotTmp in replaceDot:
#         strin = strin.replace(dotTmp," ")
        strin = strin.replace(dotTmp,"")
    for i in range(len(replaceBig)):
        strin = strin.replace(replaceBig[i],'')
        strin = strin.replace(replaceSmall[i],'')
    return strin

# %%
uri = "mongodb://travelteam:okdavid@ds011432.mlab.com:11432/imtravel" 
client = MongoClient(uri)
db = client['imtravel']
collection = db['台南']

# %%
comment = list(collection.find({},{"comment" : {"$slice":[0,1]}}))

# %%
pprint(comment['comment'][0]['content'][0])
# Out:
# ['好大的博物館',
#  '雖然知道奇美博物館規模及故事，但親臨現場還是被這座博物館的規模給震憾到，很可惜只停留兩個小時，只完成二樓藝術廳及音樂廳的部份，現在我可以確認，台灣最完整的音樂展示廳是奇美博物館。',
#  5.0,
#  '2016年5月29日']

# %%
allcomment = []

# %%
# for site in sites
comments = comment['comment'][0]['content']
for i in range(0,len(comments)):
    content = comments[i][0]+comments[i][1]
    score = {}
    score['comment'] = replace_dot(content)
    score['star'] = comments[i][2]
#     score['comment'] = "".join(score['comment'])
    allcomment.append(score)

# %%
allcomment
# Out:
# [{'comment': '好大的博物館雖然知道奇美博物館規模及故事但親臨現場還是被這座博物館的規模給震憾到很可惜只停留兩個小時只完成二樓藝術廳及音樂廳的部份現在我可以確認台灣最完整的音樂展示廳是奇美博物館',
#   'star': 5.0},
#  {'comment': '值得一遊館藏豐富環境也舒服冷氣好強應該是為了保存環境吧台南人入場免費喔另外樂器廳的演奏千萬不要錯過很精采可以逗留一整天的好地方',
#   'star': 5.0},
#  {'comment': '收藏品驚人整個佔地非常的大公園很漂亮博物館裡面動物標本最驚人還有很多化石樂器廳也非常不錯值得額外多花一點錢去聽自動樂器演奏總而言之博物館硬體很漂亮軟體收藏也很值得看',
#   'star': 5.0},
#  {'comment': '可以在這裡泡一天蓋得像皇宮博物館外有一圈護城河各個角落的裝飾及維護都很用心太陽不大的話在館外散步很舒服非當地人入館花費元但館內的收藏卻非常多有很多美麗的歐洲畫華麗傢具古代兵器相對東方的搜藏少一些也適合小朋友的動物館很多地方有椅子適合同時攜帶老人小孩我有在二樓的咖啡廳用餐氣氛不錯三明治好吃但有點貴哦',
#   'star': 5.0},
#  {'comment': '展品除了小提琴外沒有精品令人失望臺南都會公園所在地原為仁德糖廠蔗田仁德糖廠年停工後同年由當時的臺南縣政府與臺糖簽訂合作開發當中由臺糖公司提供公頃為合作開發區內由臺南縣政府集中取得回饋捐贈公頃土地臺南都會公園全區面積達公頃為臺灣面積第三大的都會公園其中公頃為第一期剩餘的公頃為第二期第一期於年月日開放',
#   'star': 3.0},
#  {'comment': '適合全家人適合全家人大小一起來喜歡拍照的人也別錯過這難得的景點只是要入內要提早預約喔每一個像都很有特色建築物很漂亮又很特別',
#   'star': 4.0},
#  {'comment': '值得一去博物館這種性質一直都是見仁見智第一層樓是動物及兵器館光這兩個地方已經看了小時二樓是比較文藝氣息的樂器等展示因為當天時間很趕來不及全部看完整體而言值得推薦',
#   'star': 4.0},
# ...

# %%
result = []
for i in range(0,len(allcomment)):
    temp = []
    tempComment = allcomment[i]
    for k in range(0,len(tempComment['comment'])-1):
        temp.append(tempComment['comment'][k]+tempComment['comment'][k+1])
    allcomment[i]['comment'] = " ".join(temp)

# %%
allcomment
# Out:
# [{'comment': '好大 大的 的博 博物 物館 館雖 雖然 然知 知道 道奇 奇美 美博 博物 物館 館規 規模 模及 及故 故事 事但 但親 親臨 臨現 現場 場還 還是 是被 被這 這座 座博 博物 物館 館的 的規 規模 模給 給震 震憾 憾到 到很 很可 可惜 惜只 只停 停留 留兩 兩個 個小 小時 時只 只完 完成 成二 二樓 樓藝 藝術 術廳 廳及 及音 音樂 樂廳 廳的 的部 部份 份現 現在 在我 我可 可以 以確 確認 認台 台灣 灣最 最完 完整 整的 的音 音樂 樂展 展示 示廳 廳是 是奇 奇美 美博 博物 物館',
#   'star': 5.0},
#  {'comment': '值得 得一 一遊 遊館 館藏 藏豐 豐富 富環 環境 境也 也舒 舒服 服冷 冷氣 氣好 好強 強應 應該 該是 是為 為了 了保 保存 存環 環境 境吧 吧台 台南 南人 人入 入場 場免 免費 費喔 喔另 另外 外樂 樂器 器廳 廳的 的演 演奏 奏千 千萬 萬不 不要 要錯 錯過 過很 很精 精采 采可 可以 以逗 逗留 留一 一整 整天 天的 的好 好地 地方',
#   'star': 5.0},
#  {'comment': '收藏 藏品 品驚 驚人 人整 整個 個佔 佔地 地非 非常 常的 的大 大公 公園 園很 很漂 漂亮 亮博 博物 物館 館裡 裡面 面動 動物 物標 標本 本最 最驚 驚人 人還 還有 有很 很多 多化 化石 石樂 樂器 器廳 廳也 也非 非常 常不 不錯 錯值 值得 得額 額外 外多 多花 花一 一點 點錢 錢去 去聽 聽自 自動 動樂 樂器 器演 演奏 奏總 總而 而言 言之 之博 博物 物館 館硬 硬體 體很 很漂 漂亮 亮軟 軟體 體收 收藏 藏也 也很 很值 值得 得看',
#   'star': 5.0},
# ...
